# %% [markdown]
# # Part 1: Creating and Manipulating Arrays
# ## Trevor Durning

# %%
# importing libraries
from matplotlib import pyplot as plt
import numpy as np

# %%
# Creating two 2D arrays
a = np.linspace(-2,2,100)
b = np.linspace(-2,2,100)

# %%
a.shape
# Out:
# (100,)

# %%
a
# Out:
# array([-2.        , -1.95959596, -1.91919192, -1.87878788, -1.83838384,
#        -1.7979798 , -1.75757576, -1.71717172, -1.67676768, -1.63636364,
#        -1.5959596 , -1.55555556, -1.51515152, -1.47474747, -1.43434343,
#        -1.39393939, -1.35353535, -1.31313131, -1.27272727, -1.23232323,
#        -1.19191919, -1.15151515, -1.11111111, -1.07070707, -1.03030303,
#        -0.98989899, -0.94949495, -0.90909091, -0.86868687, -0.82828283,
#        -0.78787879, -0.74747475, -0.70707071, -0.66666667, -0.62626263,
#        -0.58585859, -0.54545455, -0.50505051, -0.46464646, -0.42424242,
#        -0.38383838, -0.34343434, -0.3030303 , -0.26262626, -0.22222222,
#        -0.18181818, -0.14141414, -0.1010101 , -0.06060606, -0.02020202,
#         0.02020202,  0.06060606,  0.1010101 ,  0.14141414,  0.18181818,
#         0.22222222,  0.26262626,  0.3030303 ,  0.34343434,  0.38383838,
#         0.42424242,  0.46464646,  0.50505051,  0.54545455,  0.58585859,
#         0.62626263,  0.66666667,  0.70707071,  0.74747475,  0.78787879,
#         0.82828283,  0.86868687,  0.90909091,  0.94949495,  0.98989899,
#         1.03030303,  1.07070707,  1.11111111,  1.15151515,  1.19191919,
#         1.23232323,  1.27272727,  1.31313131,  1.35353535,  1.39393939,
#         1.43434343,  1.47474747,  1.51515152,  1.55555556,  1.5959596 ,
#         1.63636364,  1.67676768,  1.71717172,  1.75757576,  1.7979798 ,
#         1.83838384,  1.87878788,  1.91919192,  1.95959596,  2.        ])

# %%
b.shape
# Out:
# (100,)

# %%
b
# Out:
# array([-2.        , -1.95959596, -1.91919192, -1.87878788, -1.83838384,
#        -1.7979798 , -1.75757576, -1.71717172, -1.67676768, -1.63636364,
#        -1.5959596 , -1.55555556, -1.51515152, -1.47474747, -1.43434343,
#        -1.39393939, -1.35353535, -1.31313131, -1.27272727, -1.23232323,
#        -1.19191919, -1.15151515, -1.11111111, -1.07070707, -1.03030303,
#        -0.98989899, -0.94949495, -0.90909091, -0.86868687, -0.82828283,
#        -0.78787879, -0.74747475, -0.70707071, -0.66666667, -0.62626263,
#        -0.58585859, -0.54545455, -0.50505051, -0.46464646, -0.42424242,
#        -0.38383838, -0.34343434, -0.3030303 , -0.26262626, -0.22222222,
#        -0.18181818, -0.14141414, -0.1010101 , -0.06060606, -0.02020202,
#         0.02020202,  0.06060606,  0.1010101 ,  0.14141414,  0.18181818,
#         0.22222222,  0.26262626,  0.3030303 ,  0.34343434,  0.38383838,
#         0.42424242,  0.46464646,  0.50505051,  0.54545455,  0.58585859,
#         0.62626263,  0.66666667,  0.70707071,  0.74747475,  0.78787879,
#         0.82828283,  0.86868687,  0.90909091,  0.94949495,  0.98989899,
#         1.03030303,  1.07070707,  1.11111111,  1.15151515,  1.19191919,
#         1.23232323,  1.27272727,  1.31313131,  1.35353535,  1.39393939,
#         1.43434343,  1.47474747,  1.51515152,  1.55555556,  1.5959596 ,
#         1.63636364,  1.67676768,  1.71717172,  1.75757576,  1.7979798 ,
#         1.83838384,  1.87878788,  1.91919192,  1.95959596,  2.        ])

# %%
## Visualize each 2D array
aa, bb = np.meshgrid(a,b)

# %%
aa.shape
# Out:
# (100, 100)

# %%
bb.shape
# Out:
# (100, 100)

# %%
plt.pcolormesh(aa)

# %%
plt.pcolormesh(bb)

# %%
# Convert to cartesian coordinates
radial = np.sqrt(aa**2 + bb**2)
angle = np.arctan2(bb,aa)

# %%
# Visualize the radial coordinates
plt.pcolormesh(aa,bb,radial)

# %%
# Visualize the angle coordinates
plt.pcolormesh(bb,aa,angle)

# %%
#Calculate the quantity
d = np.cos(4*radial)**2
e = np.sin(4*angle)**2
f = e + d

# %%
f
# Out:
# array([[0.09784068, 0.04288054, 0.0152121 , ..., 0.0152121 , 0.04288054,
#         0.09784068],
#        [0.04288054, 0.00800214, 0.00231617, ..., 0.00231617, 0.00800214,
#         0.04288054],
#        [0.0152121 , 0.00231617, 0.01919286, ..., 0.01919286, 0.00231617,
#         0.0152121 ],
#        ...,
#        [0.0152121 , 0.00231617, 0.01919286, ..., 0.01919286, 0.00231617,
#         0.0152121 ],
#        [0.04288054, 0.00800214, 0.00231617, ..., 0.00231617, 0.00800214,
#         0.04288054],
#        [0.09784068, 0.04288054, 0.0152121 , ..., 0.0152121 , 0.04288054,
#         0.09784068]])

# %%
# Plot f on the x/y plane
plt.pcolormesh(aa, bb, f)

# %%
# finding the means of all y values
f_ymean = f.mean(axis=1) 
f_ymean
# Out:
# array([0.87167095, 0.83128075, 0.80375654, 0.79123944, 0.79434004,
#        0.81209051, 0.84206291, 0.88063935, 0.9234036 , 0.96561145,
#        1.00268925, 1.03070803, 1.04678378, 1.04936309, 1.03836611,
#        1.01517426, 0.98246672, 0.94392548, 0.90384242, 0.86667114,
#        0.83657168, 0.81699555, 0.81035327, 0.81779693, 0.83913723,
#        0.87289937, 0.91650772, 0.96657502, 1.0192619 , 1.0706654 ,
#        1.11719353, 1.15588556, 1.18464502, 1.20236294, 1.20892184,
#        1.20508454, 1.19228503, 1.1723488 , 1.14717803, 1.11843965,
#        1.08729353, 1.05419226, 1.01877534, 0.9798689 , 0.93558966,
#        0.88353955, 0.8210674 , 0.74564151, 0.65866214, 0.53773143,
#        0.53773143, 0.65866214, 0.74564151, 0.8210674 , 0.88353955,
#        0.93558966, 0.9798689 , 1.01877534, 1.05419226, 1.08729353,
#        1.11843965, 1.14717803, 1.1723488 , 1.19228503, 1.20508454,
#        1.20892184, 1.20236294, 1.18464502, 1.15588556, 1.11719353,
#        1.0706654 , 1.0192619 , 0.96657502, 0.91650772, 0.87289937,
#        0.83913723, 0.81779693, 0.81035327, 0.81699555, 0.83657168,
#        0.86667114, 0.90384242, 0.94392548, 0.98246672, 1.01517426,
#        1.03836611, 1.04936309, 1.04678378, 1.03070803, 1.00268925,
#        0.96561145, 0.9234036 , 0.88063935, 0.84206291, 0.81209051,
#        0.79434004, 0.79123944, 0.80375654, 0.83128075, 0.87167095])

# %%
# finding the mean of all x values
f_xmean= f.mean(axis=0)
f_xmean
# Out:
# array([0.87167095, 0.83128075, 0.80375654, 0.79123944, 0.79434004,
#        0.81209051, 0.84206291, 0.88063935, 0.9234036 , 0.96561145,
#        1.00268925, 1.03070803, 1.04678378, 1.04936309, 1.03836611,
#        1.01517426, 0.98246672, 0.94392548, 0.90384242, 0.86667114,
#        0.83657168, 0.81699555, 0.81035327, 0.81779693, 0.83913723,
#        0.87289937, 0.91650772, 0.96657502, 1.0192619 , 1.0706654 ,
#        1.11719353, 1.15588556, 1.18464502, 1.20236294, 1.20892184,
#        1.20508454, 1.19228503, 1.1723488 , 1.14717803, 1.11843965,
#        1.08729353, 1.05419226, 1.01877534, 0.9798689 , 0.93558966,
#        0.88353955, 0.8210674 , 0.74564151, 0.65866214, 0.53773143,
#        0.53773143, 0.65866214, 0.74564151, 0.8210674 , 0.88353955,
#        0.93558966, 0.9798689 , 1.01877534, 1.05419226, 1.08729353,
#        1.11843965, 1.14717803, 1.1723488 , 1.19228503, 1.20508454,
#        1.20892184, 1.20236294, 1.18464502, 1.15588556, 1.11719353,
#        1.0706654 , 1.0192619 , 0.96657502, 0.91650772, 0.87289937,
#        0.83913723, 0.81779693, 0.81035327, 0.81699555, 0.83657168,
#        0.86667114, 0.90384242, 0.94392548, 0.98246672, 1.01517426,
#        1.03836611, 1.04936309, 1.04678378, 1.03070803, 1.00268925,
#        0.96561145, 0.9234036 , 0.88063935, 0.84206291, 0.81209051,
#        0.79434004, 0.79123944, 0.80375654, 0.83128075, 0.87167095])

# %%
f_xmean.shape
# Out:
# (100,)

# %%
# Plot the mean of f with respect to the x-axis
plt.plot(f_xmean, b)

# %%
# Plot the mean of f with respect to the y axis

# %%
plt.plot(a, f_ymean)

# %% [markdown]
# # Part 2: Analyze ARGO Data

# %%
# importing libraries
import numpy as np
from matplotlib import pyplot as plt

# %%
# loading arrays
t = np.load('/data9/UN3400/work/tjd2148/float_data/T.npy')
s = np.load('/data9/UN3400/work/tjd2148/float_data/S.npy')
dep = np.load('/data9/UN3400/work/tjd2148/float_data/levels.npy')
lat = np.load('/data9/UN3400/work/tjd2148/float_data/lat.npy')
long = np.load('/data9/UN3400/work/tjd2148/float_data/lon.npy')
p = np.load('/data9/UN3400/work/tjd2148/float_data/P.npy')
date = np.load('/data9/UN3400/work/tjd2148/float_data/date.npy')

# %% [markdown]
# ### 2.2 Examine the shapes of T, S and P compared to lon, lat, date and level.

# %%
t.shape
# Out:
# (78, 75)

# %%
s.shape
# Out:
# (78, 75)

# %%
p.shape
# Out:
# (78, 75)

# %%
long.shape
# Out:
# (75,)

# %%
lat.shape
# Out:
# (75,)

# %%
dep.shape
# Out:
# (78,)

# %%
date.shape
# Out:
# (75,)

# %% [markdown]
# #### Question for 2.2: It seems there are 75 locations denoted by lat and long with each location having having a date. There are 78 depths per location reading temp, salinity, pressure.

# %% [markdown]
# ### 2.3 Make a plot for each column of data in T, S and P (three plots).

# %%
plt.plot(t, dep)
# Out:
# [<matplotlib.lines.Line2D at 0x7621614131d0>,
#  <matplotlib.lines.Line2D at 0x762160e2b590>,
#  <matplotlib.lines.Line2D at 0x76216147f4d0>,
#  <matplotlib.lines.Line2D at 0x762160e6dcd0>,
#  <matplotlib.lines.Line2D at 0x762160d806d0>,
#  <matplotlib.lines.Line2D at 0x762160fc5d50>,
#  <matplotlib.lines.Line2D at 0x762160fc7810>,
#  <matplotlib.lines.Line2D at 0x762160e24590>,
#  <matplotlib.lines.Line2D at 0x762160fc7850>,
#  <matplotlib.lines.Line2D at 0x762160fe1210>,
#  <matplotlib.lines.Line2D at 0x762160c43a50>,
#  <matplotlib.lines.Line2D at 0x762160fc73d0>,
#  <matplotlib.lines.Line2D at 0x762160d1f210>,
#  <matplotlib.lines.Line2D at 0x762160c0b310>,
#  <matplotlib.lines.Line2D at 0x762160c77f50>,
#  <matplotlib.lines.Line2D at 0x762160dac9d0>,
#  <matplotlib.lines.Line2D at 0x762160fc5990>,
#  <matplotlib.lines.Line2D at 0x762160e195d0>,
#  <matplotlib.lines.Line2D at 0x76216140aad0>,
#  <matplotlib.lines.Line2D at 0x762160d17850>,
#  <matplotlib.lines.Line2D at 0x762160e2c610>,
#  <matplotlib.lines.Line2D at 0x762161422910>,
#  <matplotlib.lines.Line2D at 0x762160df1fd0>,
#  <matplotlib.lines.Line2D at 0x762161477010>,
#  <matplotlib.lines.Line2D at 0x762160d1bdd0>,
#  <matplotlib.lines.Line2D at 0x762161486dd0>,
#  <matplotlib.lines.Line2D at 0x762160ce4d90>,
#  <matplotlib.lines.Line2D at 0x762160d5dd50>,
#  <matplotlib.lines.Line2D at 0x762160d5e1d0>,
#  <matplotlib.lines.Line2D at 0x762160f9c150>,
#  <matplotlib.lines.Line2D at 0x762160d56a90>,
#  <matplotlib.lines.Line2D at 0x762160d1f050>,
#  <matplotlib.lines.Line2D at 0x762160e24950>,
#  <matplotlib.lines.Line2D at 0x762160d272d0>,
#  <matplotlib.lines.Line2D at 0x762160da4f50>,
#  <matplotlib.lines.Line2D at 0x7621640e5010>,
#  <matplotlib.lines.Line2D at 0x762160f3f2d0>,
#  <matplotlib.lines.Line2D at 0x7621640e5b50>,
#  <matplotlib.lines.Line2D at 0x762160e24550>,
#  <matplotlib.lines.Line2D at 0x7621640e6050>,
#  <matplotlib.lines.Line2D at 0x762160efd250>,
#  <matplotlib.lines.Line2D at 0x76216147ffd0>,
#  <matplotlib.lines.Line2D at 0x7621640e4ed0>,
#  <matplotlib.lines.Line2D at 0x762160e3bb50>,
#  <matplotlib.lines.Line2D at 0x7621610db390>,
#  <matplotlib.lines.Line2D at 0x76216146bed0>,
#  <matplotlib.lines.Line2D at 0x7621640dfe50>,
#  <matplotlib.lines.Line2D at 0x7621640dd3d0>,
#  <matplotlib.lines.Line2D at 0x7621640df750>,
#  <matplotlib.lines.Line2D at 0x7621640dd710>,
#  <matplotlib.lines.Line2D at 0x7621640df7d0>,
#  <matplotlib.lines.Line2D at 0x762160c15b10>,
#  <matplotlib.lines.Line2D at 0x762160fea950>,
#  <matplotlib.lines.Line2D at 0x7621640f8fd0>,
#  <matplotlib.lines.Line2D at 0x762160d12b50>,
#  <matplotlib.lines.Line2D at 0x7621640fbdd0>,
#  <matplotlib.lines.Line2D at 0x762160d1d8d0>,
#  <matplotlib.lines.Line2D at 0x7621640f90d0>,
#  <matplotlib.lines.Line2D at 0x7621640a79d0>,
#  <matplotlib.lines.Line2D at 0x7621640fa250>,
#  <matplotlib.lines.Line2D at 0x7621640fac10>,
#  <matplotlib.lines.Line2D at 0x7621640f9ed0>,
#  <matplotlib.lines.Line2D at 0x7621640aefd0>,
#  <matplotlib.lines.Line2D at 0x76216147da50>,
#  <matplotlib.lines.Line2D at 0x7621640af210>,
#  <matplotlib.lines.Line2D at 0x7621640ad650>,
#  <matplotlib.lines.Line2D at 0x7621640af8d0>,
#  <matplotlib.lines.Line2D at 0x762160dae990>,
#  <matplotlib.lines.Line2D at 0x7621640ac5d0>,
#  <matplotlib.lines.Line2D at 0x762160f05750>,
#  <matplotlib.lines.Line2D at 0x762160da43d0>,
#  <matplotlib.lines.Line2D at 0x762160f04110>,
#  <matplotlib.lines.Line2D at 0x762160da6950>,
#  <matplotlib.lines.Line2D at 0x762160d12d10>,
#  <matplotlib.lines.Line2D at 0x762160f01810>]

# %%
plt.plot(s, dep)
# Out:
# [<matplotlib.lines.Line2D at 0x7621639fc390>,
#  <matplotlib.lines.Line2D at 0x7621639c7cd0>,
#  <matplotlib.lines.Line2D at 0x762163702190>,
#  <matplotlib.lines.Line2D at 0x762163702a90>,
#  <matplotlib.lines.Line2D at 0x762163702d50>,
#  <matplotlib.lines.Line2D at 0x762163703150>,
#  <matplotlib.lines.Line2D at 0x7621638eb610>,
#  <matplotlib.lines.Line2D at 0x762163703890>,
#  <matplotlib.lines.Line2D at 0x762163703c90>,
#  <matplotlib.lines.Line2D at 0x762163703250>,
#  <matplotlib.lines.Line2D at 0x762163710390>,
#  <matplotlib.lines.Line2D at 0x762163710750>,
#  <matplotlib.lines.Line2D at 0x762163710ad0>,
#  <matplotlib.lines.Line2D at 0x762163710ed0>,
#  <matplotlib.lines.Line2D at 0x7621637112d0>,
#  <matplotlib.lines.Line2D at 0x7621637116d0>,
#  <matplotlib.lines.Line2D at 0x762163711bd0>,
#  <matplotlib.lines.Line2D at 0x762163711e50>,
#  <matplotlib.lines.Line2D at 0x7621639aa310>,
#  <matplotlib.lines.Line2D at 0x7621689ca6d0>,
#  <matplotlib.lines.Line2D at 0x762163712a50>,
#  <matplotlib.lines.Line2D at 0x762163712dd0>,
#  <matplotlib.lines.Line2D at 0x762163823150>,
#  <matplotlib.lines.Line2D at 0x7621637133d0>,
#  <matplotlib.lines.Line2D at 0x7621637138d0>,
#  <matplotlib.lines.Line2D at 0x7621639b3c10>,
#  <matplotlib.lines.Line2D at 0x762163713f10>,
#  <matplotlib.lines.Line2D at 0x762163718350>,
#  <matplotlib.lines.Line2D at 0x762163718750>,
#  <matplotlib.lines.Line2D at 0x762163718950>,
#  <matplotlib.lines.Line2D at 0x762163718d10>,
#  <matplotlib.lines.Line2D at 0x7621637190d0>,
#  <matplotlib.lines.Line2D at 0x762163719450>,
#  <matplotlib.lines.Line2D at 0x762163719850>,
#  <matplotlib.lines.Line2D at 0x762163719c10>,
#  <matplotlib.lines.Line2D at 0x7621638afd10>,
#  <matplotlib.lines.Line2D at 0x76216381a3d0>,
#  <matplotlib.lines.Line2D at 0x7621637126d0>,
#  <matplotlib.lines.Line2D at 0x762163712a10>,
#  <matplotlib.lines.Line2D at 0x762163702dd0>,
#  <matplotlib.lines.Line2D at 0x762163713150>,
#  <matplotlib.lines.Line2D at 0x76216371b4d0>,
#  <matplotlib.lines.Line2D at 0x7621639a9410>,
#  <matplotlib.lines.Line2D at 0x76216380bb50>,
#  <matplotlib.lines.Line2D at 0x76216371bdd0>,
#  <matplotlib.lines.Line2D at 0x7621637200d0>,
#  <matplotlib.lines.Line2D at 0x762163720450>,
#  <matplotlib.lines.Line2D at 0x7621638e8910>,
#  <matplotlib.lines.Line2D at 0x762163720ed0>,
#  <matplotlib.lines.Line2D at 0x762163721050>,
#  <matplotlib.lines.Line2D at 0x762163721510>,
#  <matplotlib.lines.Line2D at 0x762163b144d0>,
#  <matplotlib.lines.Line2D at 0x762163721b50>,
#  <matplotlib.lines.Line2D at 0x76216380a010>,
#  <matplotlib.lines.Line2D at 0x76216371a3d0>,
#  <matplotlib.lines.Line2D at 0x762163722650>,
#  <matplotlib.lines.Line2D at 0x762163702ad0>,
#  <matplotlib.lines.Line2D at 0x762163e1f2d0>,
#  <matplotlib.lines.Line2D at 0x762163723110>,
#  <matplotlib.lines.Line2D at 0x76216381b5d0>,
#  <matplotlib.lines.Line2D at 0x762163b3b910>,
#  <matplotlib.lines.Line2D at 0x762163723bd0>,
#  <matplotlib.lines.Line2D at 0x762163a84110>,
#  <matplotlib.lines.Line2D at 0x76216398c450>,
#  <matplotlib.lines.Line2D at 0x76216399c810>,
#  <matplotlib.lines.Line2D at 0x762163724bd0>,
#  <matplotlib.lines.Line2D at 0x7621639fcf10>,
#  <matplotlib.lines.Line2D at 0x7621637252d0>,
#  <matplotlib.lines.Line2D at 0x7621638d0b10>,
#  <matplotlib.lines.Line2D at 0x7621638f5a10>,
#  <matplotlib.lines.Line2D at 0x762163725cd0>,
#  <matplotlib.lines.Line2D at 0x762163726090>,
#  <matplotlib.lines.Line2D at 0x762163726590>,
#  <matplotlib.lines.Line2D at 0x762163726810>,
#  <matplotlib.lines.Line2D at 0x762163726c10>]

# %%
plt.plot(p, dep)
# Out:
# [<matplotlib.lines.Line2D at 0x7621638d3950>,
#  <matplotlib.lines.Line2D at 0x76216380bc90>,
#  <matplotlib.lines.Line2D at 0x762162d2c690>,
#  <matplotlib.lines.Line2D at 0x7621637d49d0>,
#  <matplotlib.lines.Line2D at 0x762162d2cc50>,
#  <matplotlib.lines.Line2D at 0x762162d2d0d0>,
#  <matplotlib.lines.Line2D at 0x762162d2d490>,
#  <matplotlib.lines.Line2D at 0x762162d2d850>,
#  <matplotlib.lines.Line2D at 0x762162d2dc10>,
#  <matplotlib.lines.Line2D at 0x762162d2e190>,
#  <matplotlib.lines.Line2D at 0x7621637c6490>,
#  <matplotlib.lines.Line2D at 0x762162d2e850>,
#  <matplotlib.lines.Line2D at 0x7621638d6c10>,
#  <matplotlib.lines.Line2D at 0x762162d14610>,
#  <matplotlib.lines.Line2D at 0x762162d2f250>,
#  <matplotlib.lines.Line2D at 0x762163842290>,
#  <matplotlib.lines.Line2D at 0x762162d2f9d0>,
#  <matplotlib.lines.Line2D at 0x762162d2fc50>,
#  <matplotlib.lines.Line2D at 0x7621638d2bd0>,
#  <matplotlib.lines.Line2D at 0x762162d30350>,
#  <matplotlib.lines.Line2D at 0x7621637a7010>,
#  <matplotlib.lines.Line2D at 0x762162d30a10>,
#  <matplotlib.lines.Line2D at 0x762162d10d50>,
#  <matplotlib.lines.Line2D at 0x762162d31010>,
#  <matplotlib.lines.Line2D at 0x762162d31410>,
#  <matplotlib.lines.Line2D at 0x7621637f98d0>,
#  <matplotlib.lines.Line2D at 0x762162d31b90>,
#  <matplotlib.lines.Line2D at 0x76216371a050>,
#  <matplotlib.lines.Line2D at 0x762162d32310>,
#  <matplotlib.lines.Line2D at 0x762162d326d0>,
#  <matplotlib.lines.Line2D at 0x7621637bab90>,
#  <matplotlib.lines.Line2D at 0x7621637faf10>,
#  <matplotlib.lines.Line2D at 0x762162d0b290>,
#  <matplotlib.lines.Line2D at 0x762163763610>,
#  <matplotlib.lines.Line2D at 0x7621637de610>,
#  <matplotlib.lines.Line2D at 0x7621637fbc90>,
#  <matplotlib.lines.Line2D at 0x762162d33fd0>,
#  <matplotlib.lines.Line2D at 0x762162d2c450>,
#  <matplotlib.lines.Line2D at 0x762162d3c810>,
#  <matplotlib.lines.Line2D at 0x762162d3c7d0>,
#  <matplotlib.lines.Line2D at 0x762162d3ce50>,
#  <matplotlib.lines.Line2D at 0x762162d3d310>,
#  <matplotlib.lines.Line2D at 0x762162d3d6d0>,
#  <matplotlib.lines.Line2D at 0x7621637c5a10>,
#  <matplotlib.lines.Line2D at 0x762162d3dcd0>,
#  <matplotlib.lines.Line2D at 0x7621637c6150>,
#  <matplotlib.lines.Line2D at 0x7621637be510>,
#  <matplotlib.lines.Line2D at 0x762162d16890>,
#  <matplotlib.lines.Line2D at 0x762162d3eb50>,
#  <matplotlib.lines.Line2D at 0x7621639d7050>,
#  <matplotlib.lines.Line2D at 0x762162d3f310>,
#  <matplotlib.lines.Line2D at 0x762162d3f6d0>,
#  <matplotlib.lines.Line2D at 0x762162d3fa90>,
#  <matplotlib.lines.Line2D at 0x762162d3fe10>,
#  <matplotlib.lines.Line2D at 0x762162d40350>,
#  <matplotlib.lines.Line2D at 0x762162d40590>,
#  <matplotlib.lines.Line2D at 0x762162d30a50>,
#  <matplotlib.lines.Line2D at 0x762162d40cd0>,
#  <matplotlib.lines.Line2D at 0x762162d41090>,
#  <matplotlib.lines.Line2D at 0x762162d41450>,
#  <matplotlib.lines.Line2D at 0x7621639b1910>,
#  <matplotlib.lines.Line2D at 0x762162d31c90>,
#  <matplotlib.lines.Line2D at 0x762162d32050>,
#  <matplotlib.lines.Line2D at 0x762162d0a3d0>,
#  <matplotlib.lines.Line2D at 0x762162d12750>,
#  <matplotlib.lines.Line2D at 0x762162d42ad0>,
#  <matplotlib.lines.Line2D at 0x762163722e90>,
#  <matplotlib.lines.Line2D at 0x762162d0b210>,
#  <matplotlib.lines.Line2D at 0x762162d435d0>,
#  <matplotlib.lines.Line2D at 0x762162d33950>,
#  <matplotlib.lines.Line2D at 0x762162d33c90>,
#  <matplotlib.lines.Line2D at 0x762162d43f90>,
#  <matplotlib.lines.Line2D at 0x762162d442d0>,
#  <matplotlib.lines.Line2D at 0x762163814790>,
#  <matplotlib.lines.Line2D at 0x762162d44a50>]

# %% [markdown]
# ### 2.4, 2.5 Compute the mean and standard deviation of each of T, S and P at each depth in level. M make three similar plsot, but show only the mean T, S and P at each depth. Show error bars on each plot using the standard deviation')

# %%
tMean = t.mean(axis=1)
plt.plot(tMean, dep)
tStd = t.std(axis=1)
plt.errorbar(tMean, dep, yerr=tStd, fmt='-o', capsize=4)
plt.xlabel('Depth')
plt.ylabel('Mean Temperature')
plt.title('Mean Temperature vs Depth')
# Out:
# Text(0.5, 1.0, 'Mean Temperature vs Depth')

# %%
sMean = s.mean(axis=1)
plt.plot(sMean, dep)
sStd = s.std(axis=1)
plt.errorbar(sMean, dep, yerr=sStd, fmt='-o', capsize=6)
plt.xlabel('Depth')
plt.ylabel('Mean Salinity')
plt.title('Mean Salinity vs Depth')
# Out:
# Text(0.5, 1.0, 'Mean Salinity vs Depth')

# %%
pMean = p.mean(axis=1)
plt.plot(pMean, dep)
pStd = p.std(axis=1)
plt.errorbar(pMean, dep, yerr=pStd, fmt='-o', capsize=5)
plt.xlabel('Depth')
plt.ylabel('Mean Pressure')
plt.title('Mean Pressure vs Depth')
# Out:
# Text(0.5, 1.0, 'Mean Pressure vs Depth')

# %% [markdown]
# ### 2.6 Account For Missing Data

# %%
tMean = np.nanmean(t, axis=1) 
plt.plot(tMean, dep)
tStd = np.nanstd(t, axis=1)
plt.errorbar(tMean, dep, yerr=tStd, fmt='-o', capsize=4)
plt.xlabel('Depth')
plt.ylabel('Mean Temperature')
plt.title('Mean Temperature vs Depth')
# Out:
# Text(0.5, 1.0, 'Mean Temperature vs Depth')

# %%
sMean = np.nanmean(s, axis=1) 
plt.plot(sMean, dep)
sStd = np.nanstd(s, axis=1)
plt.errorbar(sMean, dep, yerr=sStd, fmt='-o', capsize=4)
plt.xlabel('Depth')
plt.ylabel('Mean Salinity')
plt.title('Mean Salinity vs Depth')
# Out:
# Text(0.5, 1.0, 'Mean Salinity vs Depth')

# %%
pMean = np.nanmean(p, axis=1) 
plt.plot(pMean, dep)
pStd = np.nanstd(p, axis=1)
plt.errorbar(pMean, dep, yerr=pStd, fmt='-o', capsize=7)
plt.xlabel('Depth')
plt.ylabel('Mean Pressure')
plt.title('Mean Pressure vs Depth')
# Out:
# Text(0.5, 1.0, 'Mean Pressure vs Depth')

# %% [markdown]
# ### 2.7 Create a scatter plot of the lon, lat positions of the ARGO float.

# %%
plt.figure(figsize=(6, 6))
plt.scatter(lat, long, c='orange')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('ARGO Positions')
plt.gca().invert_yaxis()
plt.show()
